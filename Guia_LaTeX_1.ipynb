# %% [markdown]
# # Guía de LaTeX: Primera Parte

# %% [markdown]
# ## Índice

# %% [markdown]
# * [Introducción](#Introducción)
#   - [¿Qué es LaTeX?](#¿Qué-es-LaTeX?)
#   - [MathJax](#MathJax)
# * [Elementos de sintaxis](#Elementos-de-sintaxis)
#   - [Modos matemáticos](#Modos-matemáticos)
#   - [Características básicas del lenguaje](#Características-básicas-del-lenguaje)
#   - [Entornos y numeración de ecuaciones](#Entornos-y-numeración-de-ecuaciones)
#   - [Definición de órdenes y entornos](#Definición-de-órdenes-y-entornos)
# * [Estilos matemáticos](#Estilos-matemáticos)
# * [Repertorio de símbolos matemáticos](#Repertorio-de-símbolos-matemáticos)
#   - [Acentos](#Acentos)
#   - [Letras griegas](#Letras-griegas)
#   - [Letras del alfabeto hebreo](#Letras-del-alfabeto-hebreo)
#   - [Símbolos varios](#Símbolos-varios)
#   - [Relaciones binarias](#Relaciones-binarias)
#   - [Negaciones](#Negaciones)
#   - [Operaciones binarias](#Operaciones-binarias)
#   - [Flechas](#Flechas)
# * [Símbolos de tamaño variable](#Símbolos-de-tamaño-variable)
# * [Operadores y funciones](#Operadores-y-funciones)
# * [Delimitadores](#Delimitadores)

# %% [markdown]
# ## Introducción

# %% [markdown]
# ### ¿Qué es LaTeX?
#
# [LaTeX](https://www.latex-project.org/) es un dialecto del lenguaje [TeX](https://es.wikipedia.org/wiki/TeX) inicialmente desarrollado por [Leslie Lamport](https://es.wikipedia.org/wiki/Leslie_Lamport). A su vez, TeX es un [lenguaje de marcas](https://es.wikipedia.org/wiki/Lenguaje_de_marcado) para la composición de documentos con una alta calidad tipográfica, obra de [Donald Knuth](https://es.wikipedia.org/wiki/Donald_E._Knuth). En realidad, TeX es también un lenguaje de programación, lo cual implica, en particular, que este lenguaje es extensible mediante la definición de nuevas órdenes o la modificación de las existentes. El término TeX designa, por último, el sistema tipográfico basado en el lenguaje TeX, que incluye:
# * programas intérpretes de TeX,
# * formatos (PlainTeX, LaTeX, ConTeXt...), esto es, conjuntos estructurados de órdenes que constituyen un dialecto de TeX,
# * paquetes de LaTeX, es decir, ficheros con un conjunto coherente de órdenes con una finalidad determinada,
# * programas complementarios, por ejemplo, para la creación de bibliografías o índices alfabéticos,
# * documentación,
# * ficheros de gestión de tipos de letra,
# * y multitud de ficheros auxiliares adicionales.
#
# Para utilizar LaTeX, hay que disponer, en principio, de una *distribución* de TeX en un ordenador. Las dos distribuciones principales son [MikTeX](https://miktex.org/) y [TeX Live](https://www.tug.org/texlive/). La versión para macOS de TeX Live se denomina [MacTeX](https://www.tug.org/mactex/). Cualquiera de estas distribuciones es fácil de instalar, pero exige realizar una descarga de varios gigabytes. Por ello, son de gran interés servicios web, como [Overleaf](https://www.overleaf.com/), que permiten usar TeX directamente sin más recursos que un navegador y una conexión a internet.
#
# ### MathJaX
#
# LaTeX fue concebido para generar documentos impresos. Por eso, LaTeX produce principalmente ficheros en formato pdf. Es un lenguaje bastante amplio, pues ha de cubrir todas las facetas de la producción del documento. Piénsese, por ejemplo, en un libro, en el que, además de texto, se pueden encontrar ilustraciones, tablas, listas, índices, bibliografías, etc. LaTeX cuenta, en particular, con un variado conjunto de órdenes para expresar y construir todo tipo de fórmulas y textos matemáticos.
#
# Con el paso del tiempo, LaTeX se ha convertido, de hecho, en el lenguaje estándar con el que escribir matemáticas electrónicamente en el ámbito científico. No es de extrañar, pues, que se hayan desarrollado en Javascript varias bibliotecas de funciones, como [TeXzilla](https://github.com/fred-wang/TeXZilla/), [KaTeX](https://katex.org/) y [MathJax](https://www.mathjax.org/), con el fin de que la notación matemática de LaTeX sea utilizable en la generación de páginas web. Los cuadernos Jupyter, en concreto, emplean MathJax. Cuando se procesa una celda de texto, la parte marcada como texto matemático es interpretada por MathJax y mostrada en el cuaderno mediante el uso de HTML y CSS.
#
# Conviene tener presente que MathJax y LaTeX son altamente compatibles, pero presentan algunas diferencias. Por un lado, MathJaX no implementa todos los recursos disponibles en la parte matemática de LaTeX. Por otro lado, MathJax cuenta con algunas órdenes que tienen sentido en el contexto de una página web, pero no de una página impresa, por lo que no son válidas en LaTeX estándar.

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Elementos de sintaxis
#
#
# ### Modos matemáticos
#
# MathJax procesa todo el texto que se encuentre en *modo matemático*, del cual se distinguen dos tipos. Se escriben en el *modo ordinario* las expresiones matemáticas que se entremezclan en los párrafos con el texto normal. El *modo resaltado* se emplea para destacar una expresión matemática, mostrándola en uno o más renglones separados del texto que la rodea. En una celda de un cuaderno Jupyter, la sintaxis que corresponde a cada modo es la siguiente:
#
# * modo ordinario: <code>&bsol;&bsol;(expresión matemática&bsol;&bsol;)</code> o bien `$expresión_matemática$`,
#
# * modo resaltado: <code>&bsol;&bsol;[expresión_matemática&bsol;&bsol;]</code> o bien `$$expresión_matemática$$`.
#
# En este último modo, los caracteres que acotan la expresión pueden estar en líneas independientes. Observemos asimismo que la duplicación de la barra inversa se debe a que la celda es leída primero por Markdown, lenguaje en el que, como en LaTeX, tal carácter tiene un significado especial. En LaTeX estándar, o en otro entorno de uso de MathJax, se escribe directamente <code>&bsol;(...&bsol;)</code> o <code>&bsol;[...&bsol;]</code>. También se puede entrar en modo matemático mediante los *entornos* que veremos más adelante (`equation`, `align`, etc.).
#
# Pongamos un ejemplo. Primero escribimos el código que se introduce en la celda de texto y luego el resultado obtenido al evaluarla:
#
# <hr class="ejemplo">
#
# ```
# Consideremos la ecuación de segundo grado $ax^2+bx+c=0$,
# con $a\ne0$. Su solución viene dada por la fórmula
# $$
#   x = \frac{-b \pm \sqrt{b^2-4ac}}{2a}.
# $$
# ```
# <hr class="medio">
#
# Consideremos la ecuación de segundo grado $ax^2+bx+c=0$,
# con $a\ne0$. Su solución viene dada por la fórmula
# $$
#   x = \frac{-b \pm \sqrt{b^2-4ac}}{2a}.
# $$
#
# <hr class="ejemplo">
#
# En este ejemplo, las expresiones $ax^2+bx+c=0$ y $a\ne0$ están presentadas en modo ordinario; la solución de la ecuación, en cambio, está en modo resaltado.
#
# En esta guía usaremos la sintaxis `$$...$$` para el modo matemático resaltado por simplicidad y para evitar ciertas interferencias del intérprete de Markdown a la hora de presentar código. Cabe señalar, no obstante, que no es la forma preferible en LaTeX estándar.
#
# MathJax crea en cada fórmula un menú contextual, al que se accede pulsando sobre ella con el botón derecho del ratón. Inicialmente el menú está en inglés, pero se puede pasar rápidamente al español seleccionando <span style="background: #e9e9e9; padding:1px">Language&#x25b8; español (es)</span>. Este menú da acceso a las órdenes usadas para generar la fórmula, a una ampliación para verla mejor, etc.

# %% [markdown]
# ### Características básicas del lenguaje
#
# El ejemplo dado en el apartado precedente muestra algunas características del lenguaje LaTeX  que comentamos y ampliamos a continuación:
#
# * No hacen falta órdenes especiales para escribir los símbolos matemáticos que sean directamente accesibles por el teclado. Por ejemplo, para obtener $f(x)=g'(x)+3h(x)$, basta con teclear `$f(x)=g'(x)+3h(x)$`.
#
#
# * LaTeX ignora los espacios en blanco que haya en el seno del código de una fórmula. Por ejemplo, da lo mismo `$( 1 + x) ^n \geq 1 + n x$` que `$(1+x)^n\geq 1+nx$`; en ambos casos se obtiene $(1+x)^n\geq 1+nx$. Así pues, se pueden añadir espacios para facilitar la lectura del código.
#
#
# * Al componer y presentar una expresión matemática, LaTeX ajusta automáticamente el tamaño de los caracteres, así como el espacio horizontal o vertical que los separa, según su posición en la fórmula o significado matemático. Si se quiere cambiar el espacio entre dos símbolos, hay que añadir entre ellos una de las órdenes presentadas en el cuadro siguiente:
# $$
# \newcommand{\Espacio}[1]{{\blacktriangleleft}#1{\blacktriangleright} & \textsf{#1}}
# \begin{array}{ll:ll:ll:ll}
#    \Espacio{\,} & \Espacio{\:} & \Espacio{\;} & \Espacio{\ } \\
#    \Espacio{\enspace} & \Espacio{\quad} & \Espacio{\qquad} & \Espacio{\hspace{3em}}
# \end{array}
# $$
# El espacio que cada orden intercala es el que queda entre $\blacktriangleleft$ y $\blacktriangleright$.
# La última orden de la primera fila es la barra inversa seguida de un espacio (no visible).
# La orden `\hspace` tiene un argumento obligatorio para indicar el espacio exacto que hay que dejar, expresado en unidades absolutas (`px`, `cm`...) o relativas (`em`, `ex`...). Existe asimismo la orden `\!`, que elimina espacio: compárese $xy$ (`$xy$`) con $x\!y$ (`$x\!y$`).
#
#
# * El nombre de una orden comienza con el carácter `\`. Hay órdenes sin argumentos, como `\pm` y `\ne`, y órdenes con argumentos, como `\frac` y `\sqrt`. Los argumentos obligatorios se escriben entre llaves, esto es, `{` y `}`. Veremos que hay también órdenes con argumentos opcionales, que se acotan mediante corchetes.
#
#
# * Algunos caracteres tienen un significado especial en LaTeX. Ya hemos mencionado el papel de `$`, `\`, `{` y `}`. Citemos alguno más. Los caracteres `_` y `^` sirven para escribir subíndices y superíndices (o exponentes), mientras que `%` permite añadir comentarios en las líneas de código. Por ejemplo, se obtiene $A_{ijk}^2$ con `$A_{ijk}^2$`. Observemos que las llaves se usan también para delimitar un *grupo*, esto es, una porción del código sobre el que se ejerce una acción (en este caso, situarlo como subíndice).
#
#
# El cuadro siguiente muestra algunas órdenes muy comunes, necesarias para escribir fracciones (`\frac`), raíces (`\sqrt`) y puntos suspensivos (`\ldots`, `\cdots`) o para enmarcar fórmulas (`\boxed`):
#
# $$
# \newcommand{\simb}[1]{ #1 & \textsf{#1}}
# \begin{array}{ll:ll:ll:ll}
#    \displaystyle \simb{\frac{x}{y}} & \displaystyle \simb{\binom{x}{y}} &
#       \displaystyle \simb{\sqrt[n]{m}} \\
#    \simb{1, 2,\ldots,10} & \simb{1+2+\cdots+10} & \simb{\boxed{e^{i\pi}+1=0}}
# \end{array}
# $$
#
# La lista completa de todas las órdenes que MathJax reconoce figura en una de sus [páginas de ayuda](https://docs.mathjax.org/en/latest/input/tex/macros/index.html). En apartados posteriores veremos muchas de estas órdenes.

# %% [markdown]
# ### Entornos y numeración de ecuaciones
#
# LaTeX cuenta con dos órdenes un tanto particulares, `\begin` y `\end`, que tienen, al menos, un argumento obligatorio. Van siempre emparejadas. La porción de código que acotan es un *entorno* cuyo nombre particular constituye el argumento de `\begin` y `\end`. Veremos más adelante, por ejemplo, los entornos `array` y `matrix`, que sirven para escribir cuadros y matrices. Otro entorno notable es `equation`, que se usa para entrar en modo matemático resaltado. Es equivalente poner
# ```
# $$ fórmula $$
# ```
# a escribir
# ```
# \begin{equation}
#    fórmula
# \end{equation}
# ```
# En LaTeX estándar, el entorno `equation` numera automáticamente la fórmula correspondiente. Con MathJax, en cambio, depende de cómo esté dada su configuración. En cualquier caso, siempre es posible numerar o marcar manualmente una determinada ecuación si se quiere luego hacer referencia a ella. Para ello se usan las órdenes `\label` y `\tag`. Con la primera se asocia a la ecuación una etiqueta con la que citarla; la segunda añade una marca visual a la ecuación. La referencia a la ecuación se hace luego con la orden `\eqref`.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# La *fórmula de De Moivre* establece que
# $$
#    \label{Moivre} \tag{$\ast$}
#    \DeclareMathOperator{\sen}{sen}
#    \forall n\in\mathbb{N},\ \forall\alpha\in\mathbb{R},
#    \ (\cos\alpha + i\,\sen\alpha)^n = \cos(n\alpha) + i\, \sen(n\alpha).
# $$
# Esta fórmula es muy útil para derivar expresiones de $\cos(n\alpha)$ y
# $\sen(n\alpha)$ en términos de $\cos\alpha$ y $\sen\alpha$. Por ejemplo,
# si se toma $n=2$ en la ecuación $\eqref{Moivre}$, resultan inmediatamente
# las fórmulas del ángulo duplo.
# ```
# <hr class="medio">
#
# La *fórmula de De Moivre* establece que
# $$
#    \label{Moivre} \tag{$\ast$}
#    \DeclareMathOperator{\sen}{sen}
#    \forall n\in\mathbb{N},\ \forall\alpha\in\mathbb{R},
#    \ (\cos\alpha + i\,\sen\alpha)^n = \cos(n\alpha) + i\, \sen(n\alpha).
# $$
# Esta fórmula es muy útil para derivar expresiones de $\cos(n\alpha)$ y
# $\sen(n\alpha)$ en términos de $\cos\alpha$ y $\sen\alpha$. Por ejemplo,
# si se toma $n=2$ en la ecuación $\eqref{Moivre}$, resultan inmediatamente
# las fórmulas del ángulo duplo.
#
# <hr class="ejemplo">

# %% [markdown]
# ### Definición de órdenes y entornos
#
# El lenguaje LaTeX es extensible y modificable, pues se pueden definir nuevos entornos y órdenes, o bien se puede cambiar el comportamiento de los ya existentes. Centrémonos en las órdenes. Para introducir una orden nueva o modificar una orden predefinida se usan, respectivamente, las órdenes `\newcommand` y `\renewcommand`. La sintaxis de ambas órdenes es la misma:
# ```
# \newcommand{\NuevaOrden}[NúmArgumentos][ValorPorOmisión]{Definición}
# ```
# Sólo se especifica `NúmArgumentos` si la orden tiene uno o más argumentos. Análogamente, sólo se indica `ValorOmisión` si se quiere que el primer argumento sea opcional. En `Definición` se detalla qué ha de hacer la orden. Si ésta tiene argumentos, se hace referencia a ellos con las expresiones `#1`, `#2`, etc.
#
# Para aclarar el uso de `\newcommand` y `\renewcommand`, vamos a considerar diversos ejemplos encadenados.
#
# Supongamos que queremos simplicar la escritura de la derivada de una función $f$ con la notación de Leibniz. Con tal objetivo, podríamos definir así una nueva orden llamada `\dd`: `\newcommand{\dd}{\frac{df}{dx}}`. Lo que hace esta orden simplemente es escribir $\frac{df}{dx}$. Incluimos este código en modo matemático y utilizamos la nueva función:
#
# <hr class="ejemplo">
#
# ```
# La derivada de $f(x)=x^3-3x+1$ es
# $\newcommand{\dd}{\frac{df}{dx}} \dd(x)=3x^2-3$.
# En cambio, para $f(x)=e^{3x^2}-4x$, la derivada es
# $\dd(x)=6xe^{3x^2}-4$.
# ```
#
# <hr class="medio">
#
# La derivada de $f(x)=x^3-3x+1$ es
# $\newcommand{\dd}{\frac{df}{dx}} \dd(x)=3x^2-3$.
# En cambio, para $f(x)=e^{3x^2}-4x$, la derivada es
# $\dd(x)=6xe^{3x^2}-4$.
#
# <hr class="ejemplo">
#
# Esta orden es bastante limitada, pues sólo vale para una función llamada $f$. Podemos mejorarla, dotándola de un *argumento* que será la función de la que se calcule la derivada. Al redefinir `\dd`, se indica ahora que la orden tiene un argumento, al que se hace referencia con `#1`. Al usar `\dd`, se escribe su argumento entre llaves:
#
# <hr class="ejemplo">
#
# ```
# La derivada de $f(x)=x^3-3x+1$ es
# $\renewcommand{\dd}[1]{\frac{d#1}{dx}} \dd{f}(x)=3x^2-3$.
# En cambio, para $g(x)=e^{3x^2}-4x$, la derivada es
# $\dd{g}(x)=6xe^{3x^2}-4$.
# ```
#
# <hr class="medio">
#
# La derivada de $f(x)=x^3-3x+1$ es
# $\renewcommand{\dd}[1]{\frac{d#1}{dx}} \dd{f}(x)=3x^2-3$.
# En cambio, para $g(x)=e^{3x^2}-4x$, la derivada es
# $\dd{g}(x)=6xe^{3x^2}-4$.
# <hr class="ejemplo">
#
# Podríamos ahora querer utilizar esta orden con funciones que tuvieran otra variable independiente. Necesitamos que `\dd` tenga un segundo argumento para expresar tal variable. Como habitualmente la variable es $x$, sería cómodo especificar la variable sólo si es distinta de $x$. Conviene, por ello, que se trate de un argumento opcional. Al redefinir la orden se indica entre corchetes el valor por omisión del argumento opcional, que LaTeX considera siempre que es el primero. A la hora de usar la orden, si se quiere que LaTeX asigne al argumento opcional un valor distinto del fijado por omisión, hay que proporcionarlo entre corchetes.
#
# <hr class="ejemplo">
#
# ```
# La derivada de $f(x)=x^3-3x+1$ es
# $\renewcommand{\dd}[2][x]{\frac{d#2}{d#1}} \dd{f}(x)=3x^2-3$.
# En cambio, para $g(t)=e^{3t^2}-4t$, la derivada es
# $\dd[t]{g}(t)=6te^{3t^2}-4$.
# ```
#
# <hr class="medio">
#
# La derivada de $f(x)=x^3-3x+1$ es
# $\renewcommand{\dd}[2][x]{\frac{d#2}{d#1}} \dd{f}(x)=3x^2-3$.
# En cambio, para $g(t)=e^{3t^2}-4t$, la derivada es
# $\dd[t]{g}(t)=6te^{3t^2}-4$.
#
# <hr class="ejemplo">
#
# Con la definición actual de `\dd` es fácil, por ejemplo, escribir la regla de la cadena:
#
# <hr class="ejemplo">
#
# ```
# $$
#   \dd{(g\circ f)}(x) = \dd[y]{g}(f(x))\, \dd{f}(x).
# $$
# ```
# <hr class="medio">
#
# $$
#   \dd{(g\circ f)}(x) = \dd[y]{g}(f(x))\, \dd{f}(x).
# $$
#
# <hr class="ejemplo">

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Estilos matemáticos
#
# Durante la composición de una fórmula en cualquiera de los modos
# matemáticos, LaTeX puede combinar cuatro *estilos* que afectan
# al tamaño y posición de los símbolos en las fórmulas: *resaltado* (para
# símbolos normales en modo matemático resaltado), *texto* (para símbolos
# normales en modo matemático ordinario), *índice* (para subíndices y
# superíndices de primer nivel), *índice de índice* (para subíndices y
# superíndices de segundo nivel). Los dos primeros estilos difieren
# esencialmente en el tratamiento otorgado a las fracciones, a los
# símbolos de tamaño variable (integrales, sumatorios...) y sus
# correspondientes índices, y otros operadores. Pensemos en que, en modo
# matemático ordinario, es deseable que los
# renglones de un mismo párrafo estén más o menos uniformemente
# espaciados, lo cual obliga a reducir las fórmulas en la medida de lo
# posible. Esta restricción no está presente en modo matemático
# resaltado.
#
# Consideremos, por ejemplo, la fórmula
# $$
#    (a+b)^n = \sum_{k=0}^n \binom{n}{k} a^{n-k}b^k,
# $$
# escrita con el código
# ```
# $$(a+b)^n = \sum_{k=0}^n \binom{n}{k} a^{n-k}b^k,$$
# ```
# En modo matemático ordinario, se obtiene $(a+b)^n=\sum_{k=0}^n \binom{n}{k} a^{n-k}b^k$. Comparativamente,
# se ha reducido el tamaño del sumatorio y del número combinatorio y se ha cambiado la posición de
# los índices del sumatorio. Así, por ejemplo, el estilo aplicado por LaTeX al sumatorio es,
# en el primer caso, el de tipo resaltado y, en el segundo, el de tipo texto.
#
# Por lo general, LaTeX acierta a la hora de escoger automáticamente el estilo más adecuado para cada expresión. No obstante, si hubiera que forzar un estilo determinado, se antepone una de las cuatro órdenes siguientes a la fórmula afectada: `\displaystyle`, `\textstyle`, `\scriptstyle` y `scriptscriptstyle`.
#
# Dado que las órdenes `\frac` y `\binom` son tan frecuentes, existen las variantes `\tfrac`, `\tbinom`, `\dfrac` y `\dbinom` para escribir directamente fracciones y números combinatorios en estilo de tipo texto o en el estilo resaltado.

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Repertorio de símbolos matemáticos
#
# Se ofrecen a continuación diversos cuadros que agrupan temáticamente una buena parte de los símbolos que MathJax reconoce. Junto a cada símbolo figura la orden que lo produce.

# %% [markdown]
# ### Acentos
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#     \simb{\hat{a}}   & \simb{\widehat{a}} & \simb{\tilde{a}} & \simb{\widetilde{a}} \\
#     \simb{\acute{a}} &\simb{\grave{a}}    & \simb{\bar{a}}   & \simb{\breve{a}}  \\
#     \simb{\dot{a}}   &\simb{\ddot{a}}     & \simb{\dddot{a}} &\simb{\ddddot{a}} \\
#     \simb{\check{a}} &\simb{\vec{a}}      & \simb{\mathring{a}} \\
#   \end{array}
# $$
#
# Los acentos `\widehat` y `\widetilde` se pueden aplicar a más de una letra: `$\widehat{abcd}$` y `$\widetilde{abcd}$` producen, respectivamente, $\widehat{abcd}$ y $\widetilde{abcd}$.

# %% [markdown]
# ### Letras griegas
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#      \simb{\alpha}&\simb{\beta}    &\simb{\gamma}     & \simb{\digamma} \\
#      \simb{\delta}&\simb{\epsilon} &\simb{\varepsilon}&\simb{\zeta} \\
#      \simb{\eta}  &\simb{\theta}   &\simb{\vartheta}  &\simb{\iota} \\
#      \simb{\kappa}&\simb{\varkappa}&\simb{\lambda}    &\simb{\mu}\\
#      \simb{\nu}   &\simb{\xi}      & \simb{\pi}       &\simb{\varpi} \\
#      \simb{\rho}  &\simb{\varrho}  &\simb{\sigma}     &\simb{\varsigma} \\
#      \simb{\tau}  &\simb{\upsilon} &\simb{\phi}       &\simb{\varphi}\\
#      \simb{\chi}  &\simb{\psi}     &\simb{\omega} \\ \hline
#      \simb{\Gamma}&\simb{\varGamma}&\simb{\Delta}     &\simb{\varDelta} \\
#     \simb{\Theta} &\simb{\varTheta}&\simb{\Lambda}    &\simb{\varLambda} \\
#     \simb{\Xi}    &\simb{\varXi}   &\simb{\Pi}        &\simb{\varPi}\\
#     \simb{\Sigma} &\simb{\varSigma}&\simb{\Upsilon}   &\simb{\varUpsilon}\\
#     \simb{\Phi}   &\simb{\varPhi}  &\simb{\Psi}       &\simb{\varPsi} \\
#     \simb{\Omega} &\simb{\varOmega}
#   \end{array}
# $$
#
# ### Letras del alfabeto hebreo
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#     \simb{\aleph}&\simb{\beth} &
#     \simb{\daleth}&\simb{\gimel}
#   \end{array}
# $$

# %% [markdown]
# ### Símbolos varios
#
# $$
# \begin{array}{ll:ll:ll:ll}
#     \simb{\in}           &\simb{\ni}          &\simb{\forall}      &\simb{\exists} \\
#     \simb{\emptyset}     &\simb{\infty}       &\simb{\Re}          &\simb{\Im} \\
#     \simb{\partial}      &\simb{\prime}       &\simb{\top}         &\simb{\bot} \\
#     \simb{\nabla}        &\simb{\ell}         &\simb{\imath}       &\simb{\jmath} \\
#     \simb{\wp}           &\simb{\backslash}   &\simb{\smallint}    &\simb{\triangle}\\
#     \simb{\surd}         &\simb{\hbar}        &\simb{\angle}       &\simb{\S} \\
#     \simb{\flat}         &\simb{\natural}     &\simb{\sharp}       &\simb{\neg} \\
#     \simb{\clubsuit}     &\simb{\diamondsuit} &\simb{\heartsuit}   &\simb{\spadesuit} \\
#     \simb{\square}       &\simb{\blacksquare} &\simb{\Box}         &\simb{\Diamond} \\
#     \simb{\lozenge}      &\simb{\blacklozenge}&\simb{\diagup}      &\simb{\diagdown} \\
#     \simb{\vartriangle}  &\simb{\triangledown}&\simb{\blacktriangle}
#                                               &\simb{\blacktriangledown}\\
#     \simb{\measuredangle}&\simb{\sphericalangle}&\simb{\varnothing}&\simb{\nexists} \\
#     \simb{\mho}          &\simb{\eth}           &\simb{\hslash}    & \simb{\Bbbk} \\
#     \simb{\circledS}     &\simb{\bigstar}       &\simb{\therefore} &\simb{\because}\\
#     \simb{\backprime}    &\simb{\complement}    &\simb{\Game}      &\simb{\Finv}
# \end{array}
# $$

# %% [markdown]
# ### Relaciones binarias
#
# $$
# \begin{array}{ll:ll:ll:ll}
#    \simb{\lt}               &\simb{\gt}             &\simb{\leq}              &\simb{\geq} \\
#    \simb{\leqslant}         &\simb{\geqslant}       &\simb{\leqq}             &\simb{\geqq} \\
#    \simb{\eqslantless}      &\simb{\eqslantgtr}     &\simb{\lessdot}          &\simb{\gtrdot}\\
#    \simb{\ll}               &\simb{\gg}             &\simb{\lll}              &\simb{\ggg}  \\
#    \simb{\lessgtr}          &\simb{\gtrless}        &\simb{\lesseqgtr}        &\simb{\gtreqless} \\
#    \simb{\lesssim}          &\simb{\gtrsim}         &\simb{\lessapprox}       & \simb{\gtrapprox} \\
#    \simb{\lesseqqgtr}       &\simb{\gtreqqless}     &\simb{\vartriangleleft}  & \simb{\vartriangleright}\\
#    \simb{\trianglelefteq}   &\simb{\trianglerighteq}&\simb{\blacktriangleleft}&\simb{\blacktriangleright} \\
#    \simb{\prec}             &\simb{\succ}           &\simb{\preceq}           &\simb{\succeq} \\
#    \simb{\preccurlyeq}      &\simb{\succcurlyeq}    &\simb{\curlyeqprec}      & \simb{\curlyeqsucc} \\
#    \simb{\precsim}          & \simb{\succsim}       &\simb{\precapprox}       & \simb{\succapprox} \\
#    \simb{\sim}              &\simb{\approx}         &\simb{\simeq}            &\simb{\cong} \\
#    \simb{\backsim}          &\simb{\approxeq}       &\simb{\backsimeq}        &\simb{\equiv} \\
#    \simb{\doteq}            &\simb{\doteqdot}       &\simb{\eqcirc}           &\simb{\circeq}\\
#    \simb{\fallingdotseq}    &\simb{\risingdotseq}   &\simb{\triangleq}        &\simb{\asymp}\\
#    \simb{\subset}           &\simb{\supset}         &\simb{\sqsubset}         &\simb{\sqsupset} \\
#    \simb{\subseteq}         &\simb{\supseteq}       &\simb{\sqsubseteq}       &\simb{\sqsupseteq}\\
#    \simb{\subseteqq}        &\simb{\supseteqq}      &\simb{\Subset}           &\simb{\Supset} \\
#    \simb{\smile}            &\simb{\frown}          &\simb{\mid}              &\simb{\parallel} \\
#    \simb{\smallsmile}       &\simb{\smallfrown}     &\simb{\shortmid}         &\simb{\shortparallel} \\
#    \simb{\vdash}            &\simb{\dashv}          &\simb{\vDash}            &\simb{\Vdash} \\
#    \simb{\Vvdash}           &\simb{\perp}           &\simb{\models}           &\simb{\between}\\
#    \simb{\bumpeq}           &\simb{\Bumpeq}         &\simb{\bowtie}           &\simb{\Join} \\
#    \simb{\propto}           &\simb{\pitchfork}      &\simb{\backepsilon}
# \end{array}
# $$

# %% [markdown]
# ### Negaciones
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#     \simb{\neq}             &\simb{\notin}          &\simb{\nless}            &\simb{\ngtr}\\
#     \simb{\nleq}            &\simb{\ngeq}           &\simb{\nleqslant}        &\simb{\ngeqslant}\\
#     \simb{\nleqq}           &\simb{\ngeqq}          &\simb{\lneq}             &\simb{\gneq}\\
#     \simb{\lneqq}           &\simb{\gneqq}          &\simb{\lvertneqq}        &\simb{\gvertneqq}\\
#     \simb{\lnsim}           &\simb{\gnsim}          &\simb{\lnapprox}         &\simb{\gnapprox}\\
#     \simb{\nprec}           &\simb{\nsucc}          &\simb{\npreceq}          &\simb{\nsucceq}\\
#     \simb{\precneqq}        &\simb{\succneqq}       &\simb{\precnsim}         &\simb{\succnsim}\\
#     \simb{\precnapprox}     &\simb{\succnapprox}    &\simb{\nsim}             &\simb{\ncong}\\
#     \simb{\nshortmid}       &\simb{\nshortparallel} &\simb{\nmid}             &\simb{\nparallel}\\
#     \simb{\nvdash}          &\simb{\nvDash}         &\simb{\nVdash}           &\simb{\nVDash}\\
#     \simb{\ntriangleleft}   &\simb{\ntriangleright} &\simb{\ntrianglelefteq}  &\simb{\ntrianglerighteq}\\
#     \simb{\nsubseteq}       &\simb{\nsupseteq}      &\simb{\nsubseteqq}       &\simb{\nsupseteqq}\\
#     \simb{\subsetneq}       &\simb{\supsetneq}      &\simb{\varsubsetneq}     &\simb{\varsupsetneq}\\
#     \simb{\subsetneqq}      &\simb{\supsetneqq}     &\simb{\varsubsetneqq}    &\simb{\varsupsetneqq}
#   \end{array}
# $$
#
# ### Operaciones binarias
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#     \simb{\pm}              &\simb{\mp}             &\simb{\times}            &\simb{\cdot}\\
#     \simb{\circ}            &\simb{\bigcirc}        &\simb{\div}              &\simb{\diamond}\\
#     \simb{\ast}             &\simb{\star}           &\simb{\cap}              &\simb{\cup}\\
#     \simb{\sqcap}           &\simb{\sqcup}          &\simb{\wedge}            &\simb{\vee}\\
#     \simb{\triangleleft}    &\simb{\triangleright}  &\simb{\bigtriangleup}    &\simb{\bigtriangledown}\\
#     \simb{\oplus}           &\simb{\ominus}         &\simb{\otimes}           &\simb{\oslash}\\
#     \simb{\odot}            &\simb{\bullet}         &\simb{\dagger}           &\simb{\ddagger}\\
#     \simb{\setminus}        &\simb{\uplus}          &\simb{\wr}               &\simb{\amalg}\\
#     \simb{\lhd}             &\simb{\rhd}            &\simb{\unlhd}            &\simb{\unrhd}\\
#     \simb{\dotplus}         &\simb{\centerdot}      &\simb{\ltimes}           &\simb{\rtimes}\\
#     \simb{\leftthreetimes}  &\simb{\rightthreetimes}&\simb{\circleddash}      &\simb{\smallsetminus}\\
#     \simb{\barwedge}        &\simb{\doublebarwedge} &\simb{\curlywedge}       &\simb{\curlyvee}\\
#     \simb{\veebar}          &\simb{\intercal}       &\simb{\Cap}              &\simb{\Cup}\\
#     \simb{\circledast}      &\simb{\circledcirc}    &\simb{\boxminus}         &\simb{\boxtimes}\\
#     \simb{\boxdot}          &\simb{\boxplus}        &\simb{\divideontimes}    &\simb{\And}
#   \end{array}
# $$

# %% [markdown]
# ### Flechas
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#     \simb{\leftarrow}     &\simb{\rightarrow}\textsf{ o \to}
#                           &\simb{\longleftarrow}  &\simb{\longrightarrow}\\
#     \simb{\Leftarrow}     &\simb{\Rightarrow}     &\simb{\Longleftarrow}
#                           &\simb{\Longrightarrow}\textsf{ o \implies}\\
#     \simb{\leftrightarrow}&\simb{\longleftrightarrow}&\simb{\Leftrightarrow}&\simb{\Longleftrightarrow}\\
#     \simb{\uparrow}       &\simb{\downarrow}      &\simb{\Uparrow}          &\simb{\Downarrow}\\
#     \simb{\updownarrow}   &\simb{\Updownarrow}    &\simb{\mapsto}           &\simb{\longmapsto}\\
#     \simb{\nearrow}       &\simb{\searrow}        &\simb{\swarrow}          &\simb{\nwarrow}\\
#     \simb{\hookleftarrow} &\simb{\hookrightarrow} &\simb{\rightleftharpoons}&\simb{\leftrightharpoons} \\
#     \simb{\leftharpoonup} &\simb{\rightharpoonup} &\simb{\leftharpoondown}  &\simb{\rightharpoondown}\\
#     \simb{\leadsto}       &\simb{\multimap}       &\simb{\Lleftarrow}       &\simb{\Rrightarrow}\\
#     \simb{\leftleftarrows}&\simb{\rightrightarrows}&\simb{\leftrightarrows} &\simb{\rightleftarrows}\\
#     \simb{\twoheadleftarrow}&\simb{\twoheadrightarrow}&\simb{\leftarrowtail}&\simb{\rightarrowtail}\\
#     \simb{\dashleftarrow} &\simb{\dashrightarrow} &\simb{\looparrowleft}    &\simb{\looparrowright}\\
#     \simb{\curvearrowleft}&\simb{\curvearrowright}&\simb{\circlearrowleft}  &\simb{\circlearrowright}\\
#     \simb{\Lsh}           &\simb{\Rsh}            &\simb{\upuparrows}       &\simb{\downdownarrows}\\
#     \simb{\upharpoonleft} &\simb{\upharpoonright} &\simb{\downharpoonleft}  &\simb{\downharpoonright}\\
#     \simb{\leftrightsquigarrow}&\simb{\rightsquigarrow}&\simb{\nleftarrow}  &\simb{\nrightarrow}\\
#     \simb{\nLeftarrow}    &\simb{\nRightarrow}    &\simb{\nleftrightarrow}  &\simb{\nLeftrightarrow}
#   \end{array}
# $$

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Símbolos de tamaño variable
#
# Algunos símbolos matemáticos, que, por lo general, admiten índices,
# cambian de tamaño según el contexto en que se encuentre la fórmula.
# Es el caso de los sumatorios y de los signos de integración.  El
# cuadro siguiente muestra los símbolos disponibles, así como el
# tamaño y la posición de los índices que le corresponden al símbolo en
# función del estilo (texto o resaltado) en que sea procesado.
# $$
#   \renewcommand{\simb}[1]{ #1 & \textsf{#1}}
#   \newcommand{\ORDEN}[1]{#1_{mm}^{nn} & \displaystyle #1_{mm}^{nn} & \textsf{#1_{mm}^{nn}}}
#   \newcommand{\ORDEN}[1]{#1_{mm}^{nn} & \displaystyle #1_{mm}^{nn} & \textsf{#1}\underline{ }\textsf{{mm}^{nn}}}
#   \begin{array}{lll:lll}
#     \ORDEN{\prod} & \ORDEN{\coprod} \\
#     \ORDEN{\bigcup} & \ORDEN{\bigcap} \\
#     \ORDEN{\bigwedge} & \ORDEN{\bigvee} \\
#     \ORDEN{\bigsqcup} & \ORDEN{\biguplus} \\
#     \ORDEN{\bigotimes} & \ORDEN{\bigodot} \\
#     \ORDEN{\bigoplus} &  \ORDEN{\sum} \\
#     \ORDEN{\int} & \ORDEN{\oint} \\
#     \ORDEN{\iint} & \ORDEN{\iiint} \\
#     \ORDEN{\idotsint}
#   \end{array}
# $$
#
# Los índices están situados a un lado del símbolo o debajo/encima de
# éste.  Para variar la colocación por omisión de los índices reflejada
# en el cuadro precedente, se usan las órdenes `\nolimits` (fuerza la
# posición lateral) y `\limits` (índices arriba o abajo del símbolo). Compárese
# la integral
# $$
#    \int_a^b f(x)\,dx
# $$
# obtenida con `$$\int_a^b f(x)\,dx$$`, con la integral
# $$
#    \int\limits_a^b f(x)\,dx
# $$
# que resulta del código `$$\int\limits_a^b f(x)\,dx$$`.

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Operadores y funciones
#
# El siguiente cuadro detalla las órdenes predefinidas para denotar
# algunos operadores (determinante, límite, máximo, mínimo, etc.) y
# varias funciones (seno, coseno, tangente, funciones hiperbólicas, logaritmos...):
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#      \simb{\arccos}    & \simb{\arcsin} & \simb{\arctan}    & \simb{\arg} \\
#      \simb{\cos}       & \simb{\cosh}   & \simb{\cot}       & \simb{\coth} \\
#      \simb{\csc}       & \simb{\deg}    & \simb{\det}       & \simb{\dim}  \\
#      \simb{\exp}       & \simb{\gcd}    & \simb{\hom}       & \simb{\inf}  \\
#      \simb{\injlim}    & \simb{\ker}    & \simb{\lg}        & \simb{\lim}  \\
#      \simb{\liminf}    & \simb{\limsup} & \simb{\ln}        & \simb{\log} \\
#      \simb{\max}       & \simb{\min}    & \simb{\Pr}        & \simb{\projlim} \\
#      \simb{\sec}       & \simb{\sin}    & \simb{\sinh}      & \simb{\sup}    \\
#      \simb{\tan}       & \simb{\tanh}   & \simb{\varinjlim} & \simb{\varliminf} \\
#      \simb{\varlimsup} & \simb{\varprojlim}
#   \end{array}
# $$
#
# Además, para escribir congruencias, existen las órdenes `bmod` y `pmod`.  Así, las expresiones
# $3\equiv 1\pmod 2$ y $1=3 \bmod 2$ se obtienen, respectivamente, con `$3\equiv 1\pmod 2$` y `$1=3\bmod 2$`.
#
# Algunos operadores, como los relacionados con límites (`lim`, `liminf`...), admiten índices, cuya posición
# depende del estilo (texto o resaltado) con el que se procese la fórmula.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# Es bien sabido que $e^x-1\sim x$, si $x\to 0$, ya que
# $\lim_{x\to 0} (e^x-1)/x=1$. También es cierto que $1-\cos x\sim x^2/2$
# si $x\to 0$. Por tanto,
# $$
#     \lim_{x\to 0} \frac{(e^x-1)^2}{1-\cos^3 x}
#     =\lim_{x\to 0} \frac{(e^x-1)^2}{(1-\cos x)(1+\cos x+\cos^2 x)}
#     =\lim_{x\to 0} \frac{x^2}{3x^2/2}=\frac{2}{3}.
# $$
# ```
#
# <hr class="medio">
#
# Es bien sabido que $e^x-1\sim x$, si $x\to 0$, ya que
# $\lim_{x\to 0} (e^x-1)/x=1$. También es cierto que $1-\cos x\sim x^2/2$
# si $x\to 0$. Por tanto,
# $$
#     \lim_{x\to 0} \frac{(e^x-1)^2}{1-\cos^3 x}
#     =\lim_{x\to 0} \frac{(e^x-1)^2}{(1-\cos x)(1+\cos x+\cos^2 x)}
#     =\lim_{x\to 0} \frac{x^2}{3x^2/2}=\frac{2}{3}.
# $$
# <hr class="ejemplo">
#
# Algunas de las órdenes dadas han de ser adaptadas al escribir en español, pues, por omisión, reflejan la notación inglesa. Se puede cambiar permanentemente la definición de cualquiera de ellas con la orden `\DeclareMathOperator`, que también se puede utilizar para definir nuevos operadores y funciones.
# Una vez dada una orden `\DeclareMathOperator`, no hace falta repetirla en más fórmulas, pues su efecto  se extiende a todas las expresiones matemáticas en celdas que se evalúen posteriormente.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# Recordemos las fórmulas del ángulo duplo:
# $$
#    \DeclareMathOperator{\sin}{sen}
#    \DeclareMathOperator{\tan}{tg}
#    \sin2\alpha = 2\sin\alpha\cos\alpha,
#    \quad \cos2\alpha = \cos^2\alpha-\sin^2\alpha,
#    \quad \tan2\alpha = \frac{2\tan\alpha}{1-\tan^2\alpha}
# $$
# ```
# <hr class="medio">
#
# Recordemos las fórmulas del ángulo duplo:
# $$
#    \DeclareMathOperator{\sin}{sen}
#    \DeclareMathOperator{\tan}{tg}
#    \sin2\alpha = 2\sin\alpha\cos\alpha,
#    \quad \cos2\alpha = \cos^2\alpha-\sin^2\alpha,
#    \quad \tan2\alpha = \frac{2\tan\alpha}{1-\tan^2\alpha}
# $$
# <hr class="ejemplo">
#
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# La función inversa del seno hiperbólico se denomina *argumento seno hiperbólico*.
# Su expresión explícita es
# $$
#    \DeclareMathOperator{argsinh}{Arg\,Sh}
#    \argsinh x = \log(x+\sqrt{1+x^2}).
# $$
# Observemos que
# $$
#    \int_0^x \frac{1}{\sqrt{1+t^2}}\,dt = \argsinh x.
# $$```
# <hr class="medio">
#
# La función inversa del seno hiperbólico se denomina *argumento seno hiperbólico*.
# Su expresión explícita es
# $$
#    \DeclareMathOperator{argsinh}{Arg\,Sh}
#    \argsinh x = \log(x+\sqrt{1+x^2}).
# $$
# Observemos que
# $$
#    \int_0^x \frac{1}{\sqrt{1+t^2}}\,dt = \argsinh x.
# $$
# <hr class="ejemplo">
#
# Si se va a emplear una función o un operador tan sólo unas pocas veces, no hace falta definirla con `\DeclareMathOperator`. Se puede escribir su nombre con la orden `\operatorname`.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# Dados dos conjuntos cualesquiera $A$ y $B$, el cardinal de $A\cup B$ satisface la relación
# $$
#    \operatorname{card}(A\cup B) \leq \operatorname{card}(A) + \operatorname{card}(B).
# $$
# ```
#
# <hr class="medio">
#
# Dados dos conjuntos cualesquiera $A$ y $B$, el cardinal de $A\cup B$ satisface la relación
# $$
#    \operatorname{card}(A\cup B) \leq \operatorname{card}(A) + \operatorname{card}(B).
# $$
# <hr class="ejemplo">

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# ## Delimitadores
#
# Los delimitadores son símbolos que, a modo de paréntesis, acotan o
# encierran una expresión matemática.  El cuadro siguiente indica los más comunes:
#
# $$
#   \begin{array}{ll:ll:ll:ll}
#      ( & \mathtt{(} & ) & \mathtt{)}
#        & \simb{\lbrace} \textsf{ o } \mathtt{\backslash\{}
#        & \simb{\rbrace} \textsf{ o } \mathtt{\backslash\}}  \\
#      \simb{\lbrack}\ \textsf{ o }\ \mathtt{[}
#        & \simb{\rbrack}\ \textsf{ o }\ \mathtt{]}
#        & \simb{\langle} & \simb{\rangle}\\
#      \simb{\lfloor}     & \simb{\rfloor}     & \simb{\lceil} & \simb{\rceil}  \\
#      \simb{\lvert}      & \simb{\rvert}      & \simb{\lVert} & \simb{\rVert} \\
#      \simb{\lmoustache} & \simb{\rmoustache} &\simb{\lgroup} &\simb{\rgroup}
#   \end{array}
# $$
#
# El tamaño de los delimitadores se adapta automáticamente al de la fórmula que engloban si aquéllos van precedidos de las órdenes `\left` y `\right`. Si se prefiere, se puede seleccionar manualmente el tamaño con los pares de órdenes `\bigl`-`\bigr`, `\Bigl`-`\Bigr`, `\biggl`-`\biggr` y `\Biggl`-`\Biggr`.
#
# #### Ejemplo
# <hr class="ejemplo">
#
# ```
# $$
#    \nabla \times \mathbf{F}
#    = \left( \frac{\partial F_3}{\partial y} - \frac{\partial F_2}{\partial z} \right) \mathbf{i}
#      + \left( \frac{\partial F_1}{\partial z} - \frac{\partial F_3}{\partial x} \right) \mathbf{j}
#      + \left( \frac{\partial F_2}{\partial x} - \frac{\partial F_1}{\partial y} \right) \mathbf{k}
# $$
# ```
# <hr class="medio">
#
# $$
#    \nabla \times \mathbf{F}
#    = \left( \frac{\partial F_3}{\partial y} - \frac{\partial F_2}{\partial z} \right) \mathbf{i}
#      + \left( \frac{\partial F_1}{\partial z} - \frac{\partial F_3}{\partial x} \right) \mathbf{j}
#      + \left( \frac{\partial F_2}{\partial x} - \frac{\partial F_1}{\partial y} \right) \mathbf{k}
# $$
# <hr class="ejemplo">
#
# #### Ejemplo
# <hr class="ejemplo">
#
# ```
# $$
#    \int_0^1 x^3\,dx = \left[ \frac{x^4}{4} \right]_{x=0}^{x=1} = \frac{1}{4}
# $$
# ```
# <hr class="medio">
#
# $$
#    \int_0^1 x^3\,dx = \left[ \frac{x^4}{4} \right]_{x=0}^{x=1} = \frac{1}{4}
# $$
# <hr class="ejemplo">
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# $$
#    \biggl\lVert \biggl( \frac{1}{2}, \frac{\sqrt{3}}{2} \biggr) \biggr\rVert
#    = \Biggl( \biggl(\frac{1}{2}\biggr)^2 + \biggl(\frac{\sqrt{3}}{2}\biggr)^2 \Biggr)^{1/2}
#    = \biggl(\frac{1}{4} + \frac{3}{4}\biggr)^{1/2} = 1
# $$
# ```
# <hr class="medio">
#
# $$
#    \biggl\lVert \biggl( \frac{1}{2}, \frac{\sqrt{3}}{2} \biggr) \biggr\rVert
#    = \Biggl( \biggl(\frac{1}{2}\biggr)^2 + \biggl(\frac{\sqrt{3}}{2}\biggr)^2 \Biggr)^{1/2}
#    = \biggl(\frac{1}{4} + \frac{3}{4}\biggr)^{1/2} = 1
# $$
# <hr class="ejemplo">
#
# Toda orden `\left` lleva aparejada una orden `\right`. Si una fórmula sólo tiene delimitador a un lado, se sustituye por un punto el delimitador que haya que omitir.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# $$
#   (\mathcal{P})
#   \left\{
#   \begin{aligned}
#      &\sigma\in H^m(\Omega), \\
#      &\forall v\in H^m(\Omega),\ J(\sigma)\leq J(v).
#   \end{aligned}
#   \right.
# $$
# ````
# <hr class="medio">
#
# $$
#   (\mathcal{P})
#   \left\{
#   \begin{aligned}
#      &\sigma\in H^m(\Omega), \\
#      &\forall v\in H^m(\Omega),\ J(\sigma)\leq J(v).
#   \end{aligned}
#   \right.
# $$
# <hr class="ejemplo">
#
# Hay otros símbolos que se pueden usar como delimitadores, siempre y cuando vayan precedidos de `\left`, `\right`, `\bigl`, etc. Así ocurre con `/`,  `\backslash` ($\backslash$), `\vert` ($\vert$), `\Vert`($\Vert$), `\uparrow`($\uparrow$), `\downarrow`($\downarrow$),
# `\Uparrow`($\Uparrow$), `\Downarrow`($\Downarrow$),
# `\updownarrow`($\updownarrow$) y `\Updownarrow`($\Updownarrow$). También existen las órdenes `\bigm`, `\Bigm`, `\biggm` y `\Biggm` para alargar estos delimitadores cuando son usados como operadores o relaciones binarias, así como `\big`, `\Big`, `\bigg` y `\Bigg` si no se quiere que se genere espacio adicional junto al delimitador.
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# $$
#    A = \biggl\{ x\in\mathbb{R} \biggm\vert \frac{x^2+10}{x^2+3}<2 \biggr\}
# $$
# ```
# <hr class="medio">
#
# $$
#    A = \biggl\{ x\in\mathbb{R} \biggm\vert \frac{x^2+10}{x^2+3}<2 \biggr\}
# $$
# <hr class="ejemplo">
#
# #### Ejemplo
#
# <hr class="ejemplo">
#
# ```
# $$
#    f(x) = \frac{x^2+10}{x^2+3} \implies \frac{df}{dx}(2)
#       = \frac{-14x}{(x^2+3)^2}\bigg\vert_{x=2} = -\frac{4}{7}
# $$
# ```
# <hr class="medio">
#
# $$
#    f(x) = \frac{x^2+10}{x^2+3} \implies \frac{df}{dx}(2)
#       = \frac{-14x}{(x^2+3)^2}\bigg\vert_{x=2} = -\frac{4}{7}
# $$
#
# <hr class="ejemplo">

# %% [markdown]
# <div style="text-align:right">
# <a href=#Índice
#    style="padding:0.5em;background:#7d5d3b;color:#ffffff;text-decoration:none;
#           border:1px solid #54381e;border-radius:5px;">Volver al índice</a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Celda de configuración</strong>.
# La evaluación de la celda siguiente cambia el formato por omisión de este cuaderno.
# </div>

# %%
# %%html
# <style>
# h1{text-align: center; color: rgb(185,74,72);}
# h2{text-align: center; color: rgb(0,102,0); padding: 0.25em 0;
#    border: 2px solid rgb(0,191,0); border-width: 2px 0;}
# h3{border-bottom: 2px solid rgb(153,153,153);}
# h4{color: rgb(58,135,173); font-size: 115%!important;
#    font-weight: bold!important;}
# .text_cell_render{font-family: "Trebuchet MS",Geneva,sans-serif;
#                   font-size: 110%; line-height: 1.5;}
# .MathJax_Display{margin: 0.5em 0;}
# th, td{font-size: larger;}
# hr.ejemplo{border: 1px solid rgb(58,135,173); background: white;}
# hr.medio{border: 1px dashed gray; background: white;}
# </style>
# Out:
# <style>
# h1{text-align: center; color: rgb(185,74,72);}
# h2{text-align: center; color: rgb(0,102,0); padding: 0.25em 0;
#    border: 2px solid rgb(0,191,0); border-width: 2px 0;}
# h3{border-bottom: 2px solid rgb(153,153,153);}
# h4{color: rgb(58,135,173); font-size: 115%!important;
#    font-weight: bold!important;}
# .text_cell_render{font-family: "Trebuchet MS",Geneva,sans-serif;
#                   font-size: 110%; line-height: 1.5;}
# .MathJax_Display{margin: 0.5em 0;}
# th, td{font-size: larger;}
# hr.ejemplo{border: 1px solid rgb(58,135,173); background: white;}
# hr.medio{border: 1px dashed gray; background: white;}
# </style>

# %% [markdown]
# <div class="alert alert-success">
# Realizado por <emph>Juan José Torrens</emph> para la asignatura de <strong>Cálculo II</strong><br>
# Grados de <strong>Ciencias</strong> y de <strong>Ciencia de Datos</strong><br>
# Universidad Pública de Navarra<br>
# Última versión: 15-1-2021
# </div>
